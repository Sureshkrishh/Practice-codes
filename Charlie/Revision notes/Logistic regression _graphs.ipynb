# %%
for i in Xbin_combined:
    if i == 'Start_Tech_Oscar':
        continue
    else:
        plt.figure()
        sns.barplot(x= i, y= 'Start_Tech_Oscar', data= Xbin_combined)
        plt.hlines(y= 0.4545, xmin= -0.1, xmax= 9.0, colors='red', ls='-.')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
